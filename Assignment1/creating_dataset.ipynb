# %%
import pandas as pd

student_data = {
    "Name": ["Uday", "Akshay", "Aman", "Gaurav", "Mohit"],
    "Branch": ["Comp", "ENTC", "IT", "Comp", "IT"]
}

df = pd.DataFrame(student_data)

print(df)

df.to_csv("students.csv", index=False)
# Out:
#      Name Branch
# 0    Uday   Comp
# 1  Akshay   ENTC
# 2    Aman     IT
# 3  Gaurav   Comp
# 4   Mohit     IT

# %%
# !ls
# Out:
#  anaconda3		  eclipse		        nltk_data
#  anaconda_projects	  eclipse-workspace	        Pictures
# 'archive (1).zip'	  Edraw			        Public
#  creating_dataset.ipynb   employee_salary_dataset.csv   snap
#  Desktop		  firstfir.cpp		        students.csv
#  Documents		  loading_local_dataset.ipynb  'Untitled Folder'
#  Downloads		  mongo-cxx-driver	        Videos
