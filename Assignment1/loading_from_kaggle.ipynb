# %%
# !pip install opendatasets
# !pip install pandas
# !pip install kaggle
# Out:
# Requirement already satisfied: opendatasets in ./anaconda3/lib/python3.12/site-packages (0.1.22)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.12/site-packages (from opendatasets) (4.66.5)
# Requirement already satisfied: kaggle in ./anaconda3/lib/python3.12/site-packages (from opendatasets) (1.8.3)
# Requirement already satisfied: click in ./anaconda3/lib/python3.12/site-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: black>=24.10.0 in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (25.12.0)
# Requirement already satisfied: bleach in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (1.19.1)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (24.1)
# Requirement already satisfied: protobuf in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (4.25.3)
# Requirement already satisfied: python-dateutil in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: six>=1.10 in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: types-requests in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in ./anaconda3/lib/python3.12/site-packages (from kaggle->opendatasets) (2.2.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle->opendatasets) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle->opendatasets) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle->opendatasets) (3.10.0)
# Requirement already satisfied: pytokens>=0.3.0 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle->opendatasets) (0.3.0)
# Requirement already satisfied: typing_extensions>=4.6.0 in ./anaconda3/lib/python3.12/site-packages (from mypy>=1.15.0->kaggle->opendatasets) (4.11.0)
# Requirement already satisfied: librt>=0.6.2 in ./anaconda3/lib/python3.12/site-packages (from mypy>=1.15.0->kaggle->opendatasets) (0.7.7)
# Requirement already satisfied: webencodings in ./anaconda3/lib/python3.12/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./anaconda3/lib/python3.12/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (2025.4.26)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: kaggle in ./anaconda3/lib/python3.12/site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in ./anaconda3/lib/python3.12/site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in ./anaconda3/lib/python3.12/site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in ./anaconda3/lib/python3.12/site-packages (from kaggle) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in ./anaconda3/lib/python3.12/site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.12/site-packages (from kaggle) (24.1)
# Requirement already satisfied: protobuf in ./anaconda3/lib/python3.12/site-packages (from kaggle) (4.25.3)
# Requirement already satisfied: python-dateutil in ./anaconda3/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in ./anaconda3/lib/python3.12/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.12/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: six>=1.10 in ./anaconda3/lib/python3.12/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.12/site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: types-requests in ./anaconda3/lib/python3.12/site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in ./anaconda3/lib/python3.12/site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in ./anaconda3/lib/python3.12/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: click>=8.0.0 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (3.10.0)
# Requirement already satisfied: pytokens>=0.3.0 in ./anaconda3/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: typing_extensions>=4.6.0 in ./anaconda3/lib/python3.12/site-packages (from mypy>=1.15.0->kaggle) (4.11.0)
# Requirement already satisfied: librt>=0.6.2 in ./anaconda3/lib/python3.12/site-packages (from mypy>=1.15.0->kaggle) (0.7.7)
# Requirement already satisfied: webencodings in ./anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./anaconda3/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.12/site-packages (from requests->kaggle) (2025.4.26)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !kaggle datasets download -d uciml/iris
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# License(s): CC0-1.0
# Downloading iris.zip to /home/csl4
#   0%|                                               | 0.00/3.60k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 3.60k/3.60k [00:00<00:00, 4.47MB/s]

# %%
# !unzip iris.zip
# Out:
# Archive:  iris.zip
#   inflating: Iris.csv
#   inflating: database.sqlite

# %%
import pandas as pds

# reading the XLSX file
file =("Iris.csv")
data = pds.read_csv(file)

# displaying the contents of the XLSX file

# first 5 rows
display(data.head())

# number of rows and columns as (rows, columns)
print(data.shape)

# column names
print(list(data.columns))

print(data.info())

print(data.describe())

# number of null values for each column
print(data.isnull().sum())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# (150, 6)
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
